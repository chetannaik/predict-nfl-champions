# %% [markdown]
# #NFL Linear Regression Paired Data

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from collections import defaultdict

import cPickle as pickle
import numpy as np
import pandas as pd
import pylab
import statsmodels.api as sm

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
import seaborn
colors = seaborn.color_palette()

from matplotlib import rc

rc("figure", facecolor="white")
rc("axes", facecolor="white")
rc("axes", edgecolor="grey")


rc("grid", alpha=0.9)
rc("grid", linewidth=0.2)
rc("grid", linestyle=":")


rc('font',**{'family':'serif','serif':['Palatino']})

# %% [markdown]
# ---

# %%
trainDF = pd.read_csv('trainNFL.csv', index_col=0)
testDF = pd.read_csv('testNFL.csv', index_col=0)

# %%
trainDF['score_diff'] = trainDF.home_score - trainDF.away_score
testDF['score_diff'] = testDF.home_score - testDF.away_score

# %%
trainDF = trainDF.sort(column='game_id').reset_index(drop=True)
testDF = testDF.sort(column='game_id').reset_index(drop=True)
# Out:
# /Library/Python/2.7/site-packages/pandas-0.13.1_213_gc174c3d-py2.7-macosx-10.9-intel.egg/pandas/core/frame.py:2542: FutureWarning: column is deprecated, use columns
#   warnings.warn("column is deprecated, use columns", FutureWarning)

# %%
trainDF['1QP_diff'] = trainDF['1QP_home'] - trainDF['1QP_away']
trainDF['2QP_diff'] = trainDF['2QP_home'] - trainDF['2QP_away']
trainDF['3QP_diff'] = trainDF['3QP_home'] - trainDF['3QP_away']
trainDF['4QP_diff'] = trainDF['4QP_home'] - trainDF['4QP_away']
trainDF['RFD_diff'] = trainDF['RFD_home'] - trainDF['RFD_away']
trainDF['PFD_diff'] = trainDF['PFD_home'] - trainDF['PFD_away']
trainDF['IFD_diff'] = trainDF['IFD_home'] - trainDF['IFD_away']
trainDF['RY_diff'] = trainDF['RY_home'] - trainDF['RY_away']
trainDF['RA_diff'] = trainDF['RA_home'] - trainDF['RA_away']
trainDF['PY_diff'] = trainDF['PY_home'] - trainDF['PY_away']
trainDF['PA_diff'] = trainDF['PA_home'] - trainDF['PA_away']
trainDF['PC_diff'] = trainDF['PC_home'] - trainDF['PC_away']
trainDF['SK_diff'] = trainDF['SK_home'] - trainDF['SK_away']
trainDF['INT_diff'] = trainDF['INT_home'] - trainDF['INT_away']
trainDF['FUM_diff'] = trainDF['FUM_home'] - trainDF['FUM_away']
trainDF['PU_diff'] = trainDF['PU_home'] - trainDF['PU_away']
trainDF['GPY_diff'] = trainDF['GPY_home'] - trainDF['GPY_away']
trainDF['PR_diff'] = trainDF['PR_home'] - trainDF['PR_away']
trainDF['PRY_diff'] = trainDF['PRY_home'] - trainDF['PRY_away']
trainDF['KR_diff'] = trainDF['KR_home'] - trainDF['KR_away']
trainDF['KRY_diff'] = trainDF['KRY_home'] - trainDF['KRY_away']
trainDF['IR_diff'] = trainDF['IR_home'] - trainDF['IR_away']
trainDF['IRY_diff'] = trainDF['IRY_home'] - trainDF['IRY_away']
trainDF['PEN_diff'] = trainDF['PEN_home'] - trainDF['PEN_away']
trainDF['TOP_diff'] = trainDF['TOP_home'] - trainDF['TOP_away']
trainDF['TD_diff'] = trainDF['TD_home'] - trainDF['TD_away']
trainDF['TDR_diff'] = trainDF['TDR_home'] - trainDF['TDR_away']
trainDF['TDP_diff'] = trainDF['TDP_home'] - trainDF['TDP_away']
trainDF['TDT_diff'] = trainDF['TDT_home'] - trainDF['TDT_away']
trainDF['FGM_diff'] = trainDF['FGM_home'] - trainDF['FGM_away']
trainDF['FGAT_diff'] = trainDF['FGAT_home'] - trainDF['FGAT_away']
trainDF['FGY_diff'] = trainDF['FGY_home'] - trainDF['FGY_away']
trainDF['RZA_diff'] = trainDF['RZA_home'] - trainDF['RZA_away']
trainDF['RZC_diff'] = trainDF['RZC_home'] - trainDF['RZC_away']
trainDF['BRY_diff'] = trainDF['BRY_home'] - trainDF['BRY_away']
trainDF['BPY_diff'] = trainDF['BPY_home'] - trainDF['BPY_away']
trainDF['SRP_diff'] = trainDF['SRP_home'] - trainDF['SRP_away']
trainDF['S1RP_diff'] = trainDF['S1RP_home'] - trainDF['S1RP_away']
trainDF['S2RP_diff'] = trainDF['S2RP_home'] - trainDF['S2RP_away']
trainDF['S3RP_diff'] = trainDF['S3RP_home'] - trainDF['S3RP_away']
trainDF['SPP_diff'] = trainDF['SPP_home'] - trainDF['SPP_away']
trainDF['S1PP_diff'] = trainDF['S1PP_home'] - trainDF['S1PP_away']
trainDF['S2PP_diff'] = trainDF['S2PP_home'] - trainDF['S2PP_away']
trainDF['S3PP_diff'] = trainDF['S3PP_home'] - trainDF['S3PP_away']
trainDF['LEA_diff'] = trainDF['LEA_home'] - trainDF['LEA_away']
trainDF['LEY_diff'] = trainDF['LEY_home'] - trainDF['LEY_away']
trainDF['LTA_diff'] = trainDF['LTA_home'] - trainDF['LTA_away']
trainDF['LTY_diff'] = trainDF['LTY_home'] - trainDF['LTY_away']
trainDF['LGA_diff'] = trainDF['LGA_home'] - trainDF['LGA_away']
trainDF['LGY_diff'] = trainDF['LGY_home'] - trainDF['LGY_away']
trainDF['MDA_diff'] = trainDF['MDA_home'] - trainDF['MDA_away']
trainDF['MDY_diff'] = trainDF['MDY_home'] - trainDF['MDY_away']
trainDF['RGA_diff'] = trainDF['RGA_home'] - trainDF['RGA_away']
trainDF['RGY_diff'] = trainDF['RGY_home'] - trainDF['RGY_away']
trainDF['RTA_diff'] = trainDF['RTA_home'] - trainDF['RTA_away']
trainDF['RTY_diff'] = trainDF['RTY_home'] - trainDF['RTY_away']
trainDF['REA_diff'] = trainDF['REA_home'] - trainDF['REA_away']
trainDF['REY_diff'] = trainDF['REY_home'] - trainDF['REY_away']
trainDF['R1A_diff'] = trainDF['R1A_home'] - trainDF['R1A_away']
trainDF['R1Y_diff'] = trainDF['R1Y_home'] - trainDF['R1Y_away']
trainDF['R2A_diff'] = trainDF['R2A_home'] - trainDF['R2A_away']
trainDF['R2Y_diff'] = trainDF['R2Y_home'] - trainDF['R2Y_away']
trainDF['R3A_diff'] = trainDF['R3A_home'] - trainDF['R3A_away']
trainDF['R3Y_diff'] = trainDF['R3Y_home'] - trainDF['R3Y_away']
trainDF['QBA_diff'] = trainDF['QBA_home'] - trainDF['QBA_away']
trainDF['QBY_diff'] = trainDF['QBY_home'] - trainDF['QBY_away']
trainDF['SLA_diff'] = trainDF['SLA_home'] - trainDF['SLA_away']
trainDF['SLY_diff'] = trainDF['SLY_home'] - trainDF['SLY_away']
trainDF['SMA_diff'] = trainDF['SMA_home'] - trainDF['SMA_away']
trainDF['SMY_diff'] = trainDF['SMY_home'] - trainDF['SMY_away']
trainDF['SRA_diff'] = trainDF['SRA_home'] - trainDF['SRA_away']
trainDF['SRY_diff'] = trainDF['SRY_home'] - trainDF['SRY_away']
trainDF['DLA_diff'] = trainDF['DLA_home'] - trainDF['DLA_away']
trainDF['DLY_diff'] = trainDF['DLY_home'] - trainDF['DLY_away']
trainDF['DMA_diff'] = trainDF['DMA_home'] - trainDF['DMA_away']
trainDF['DMY_diff'] = trainDF['DMY_home'] - trainDF['DMY_away']
trainDF['DRA_diff'] = trainDF['DRA_home'] - trainDF['DRA_away']
trainDF['DRY_diff'] = trainDF['DRY_home'] - trainDF['DRY_away']
trainDF['WR1A_diff'] = trainDF['WR1A_home'] - trainDF['WR1A_away']
trainDF['WR1Y_diff'] = trainDF['WR1Y_home'] - trainDF['WR1Y_away']
trainDF['WR3A_diff'] = trainDF['WR3A_home'] - trainDF['WR3A_away']
trainDF['WR3Y_diff'] = trainDF['WR3Y_home'] - trainDF['WR3Y_away']
trainDF['TEA_diff'] = trainDF['TEA_home'] - trainDF['TEA_away']
trainDF['TEY_diff'] = trainDF['TEY_home'] - trainDF['TEY_away']
trainDF['RBA_diff'] = trainDF['RBA_home'] - trainDF['RBA_away']
trainDF['RBY_diff'] = trainDF['RBY_home'] - trainDF['RBY_away']
trainDF['SGA_diff'] = trainDF['SGA_home'] - trainDF['SGA_away']
trainDF['SGY_diff'] = trainDF['SGY_home'] - trainDF['SGY_away']
trainDF['P1A_diff'] = trainDF['P1A_home'] - trainDF['P1A_away']
trainDF['P1Y_diff'] = trainDF['P1Y_home'] - trainDF['P1Y_away']
trainDF['P2A_diff'] = trainDF['P2A_home'] - trainDF['P2A_away']
trainDF['P2Y_diff'] = trainDF['P2Y_home'] - trainDF['P2Y_away']
trainDF['P3A_diff'] = trainDF['P3A_home'] - trainDF['P3A_away']
trainDF['P3Y_diff'] = trainDF['P3Y_home'] - trainDF['P3Y_away']
trainDF['SPC_diff'] = trainDF['SPC_home'] - trainDF['SPC_away']
trainDF['MPC_diff'] = trainDF['MPC_home'] - trainDF['MPC_away']
trainDF['LPC_diff'] = trainDF['LPC_home'] - trainDF['LPC_away']
trainDF['Q1RA_diff'] = trainDF['Q1RA_home'] - trainDF['Q1RA_away']
trainDF['Q1RY_diff'] = trainDF['Q1RY_home'] - trainDF['Q1RY_away']
trainDF['Q1PA_diff'] = trainDF['Q1PA_home'] - trainDF['Q1PA_away']
trainDF['Q1PY_diff'] = trainDF['Q1PY_home'] - trainDF['Q1PY_away']
trainDF['LCRA_diff'] = trainDF['LCRA_home'] - trainDF['LCRA_away']
trainDF['LCRY_diff'] = trainDF['LCRY_home'] - trainDF['LCRY_away']
trainDF['LCPA_diff'] = trainDF['LCPA_home'] - trainDF['LCPA_away']
trainDF['LCPY_diff'] = trainDF['LCPY_home'] - trainDF['LCPY_away']
trainDF['RZRA_diff'] = trainDF['RZRA_home'] - trainDF['RZRA_away']
trainDF['RZRY_diff'] = trainDF['RZRY_home'] - trainDF['RZRY_away']
trainDF['RZPA_diff'] = trainDF['RZPA_home'] - trainDF['RZPA_away']
trainDF['RZPY_diff'] = trainDF['RZPY_home'] - trainDF['RZPY_away']
trainDF['SKY_diff'] = trainDF['SKY_home'] - trainDF['SKY_away']
trainDF['LBS_diff'] = trainDF['LBS_home'] - trainDF['LBS_away']
trainDF['DBS_diff'] = trainDF['DBS_home'] - trainDF['DBS_away']
trainDF['SFPY_diff'] = trainDF['SFPY_home'] - trainDF['SFPY_away']
trainDF['DRV_diff'] = trainDF['DRV_home'] - trainDF['DRV_away']
trainDF['NPY_diff'] = trainDF['NPY_home'] - trainDF['NPY_away']
trainDF['TB_diff'] = trainDF['TB_home'] - trainDF['TB_away']
trainDF['I20_diff'] = trainDF['I20_home'] - trainDF['I20_away']
trainDF['RTD_diff'] = trainDF['RTD_home'] - trainDF['RTD_away']
trainDF['LNR_diff'] = trainDF['LNR_home'] - trainDF['LNR_away']
trainDF['LNP_diff'] = trainDF['LNP_home'] - trainDF['LNP_away']
trainDF['LBR_diff'] = trainDF['LBR_home'] - trainDF['LBR_away']
trainDF['LBP_diff'] = trainDF['LBP_home'] - trainDF['LBP_away']
trainDF['DBR_diff'] = trainDF['DBR_home'] - trainDF['DBR_away']
trainDF['DBP_diff'] = trainDF['DBP_home'] - trainDF['DBP_away']
trainDF['NHA_diff'] = trainDF['NHA_home'] - trainDF['NHA_away']
trainDF['S3A_diff'] = trainDF['S3A_home'] - trainDF['S3A_away']
trainDF['S3C_diff'] = trainDF['S3C_home'] - trainDF['S3C_away']
trainDF['L3A_diff'] = trainDF['L3A_home'] - trainDF['L3A_away']
trainDF['L3C_diff'] = trainDF['L3C_home'] - trainDF['L3C_away']
trainDF['STF_diff'] = trainDF['STF_home'] - trainDF['STF_away']
trainDF['DP_diff'] = trainDF['DP_home'] - trainDF['DP_away']
trainDF['FSP_diff'] = trainDF['FSP_home'] - trainDF['FSP_away']
trainDF['OHP_diff'] = trainDF['OHP_home'] - trainDF['OHP_away']
trainDF['PBEP_diff'] = trainDF['PBEP_home'] - trainDF['PBEP_away']
trainDF['DLP_diff'] = trainDF['DLP_home'] - trainDF['DLP_away']
trainDF['DSP_diff'] = trainDF['DSP_home'] - trainDF['DSP_away']
trainDF['DMP_diff'] = trainDF['DMP_home'] - trainDF['DMP_away']
trainDF['PFN_diff'] = trainDF['PFN_home'] - trainDF['PFN_away']

# %%
testDF['1QP_diff'] = testDF['1QP_home'] - testDF['1QP_away']
testDF['2QP_diff'] = testDF['2QP_home'] - testDF['2QP_away']
testDF['3QP_diff'] = testDF['3QP_home'] - testDF['3QP_away']
testDF['4QP_diff'] = testDF['4QP_home'] - testDF['4QP_away']
testDF['RFD_diff'] = testDF['RFD_home'] - testDF['RFD_away']
testDF['PFD_diff'] = testDF['PFD_home'] - testDF['PFD_away']
testDF['IFD_diff'] = testDF['IFD_home'] - testDF['IFD_away']
testDF['RY_diff'] = testDF['RY_home'] - testDF['RY_away']
testDF['RA_diff'] = testDF['RA_home'] - testDF['RA_away']
testDF['PY_diff'] = testDF['PY_home'] - testDF['PY_away']
testDF['PA_diff'] = testDF['PA_home'] - testDF['PA_away']
testDF['PC_diff'] = testDF['PC_home'] - testDF['PC_away']
testDF['SK_diff'] = testDF['SK_home'] - testDF['SK_away']
testDF['INT_diff'] = testDF['INT_home'] - testDF['INT_away']
testDF['FUM_diff'] = testDF['FUM_home'] - testDF['FUM_away']
testDF['PU_diff'] = testDF['PU_home'] - testDF['PU_away']
testDF['GPY_diff'] = testDF['GPY_home'] - testDF['GPY_away']
testDF['PR_diff'] = testDF['PR_home'] - testDF['PR_away']
testDF['PRY_diff'] = testDF['PRY_home'] - testDF['PRY_away']
testDF['KR_diff'] = testDF['KR_home'] - testDF['KR_away']
testDF['KRY_diff'] = testDF['KRY_home'] - testDF['KRY_away']
testDF['IR_diff'] = testDF['IR_home'] - testDF['IR_away']
testDF['IRY_diff'] = testDF['IRY_home'] - testDF['IRY_away']
testDF['PEN_diff'] = testDF['PEN_home'] - testDF['PEN_away']
testDF['TOP_diff'] = testDF['TOP_home'] - testDF['TOP_away']
testDF['TD_diff'] = testDF['TD_home'] - testDF['TD_away']
testDF['TDR_diff'] = testDF['TDR_home'] - testDF['TDR_away']
testDF['TDP_diff'] = testDF['TDP_home'] - testDF['TDP_away']
testDF['TDT_diff'] = testDF['TDT_home'] - testDF['TDT_away']
testDF['FGM_diff'] = testDF['FGM_home'] - testDF['FGM_away']
testDF['FGAT_diff'] = testDF['FGAT_home'] - testDF['FGAT_away']
testDF['FGY_diff'] = testDF['FGY_home'] - testDF['FGY_away']
testDF['RZA_diff'] = testDF['RZA_home'] - testDF['RZA_away']
testDF['RZC_diff'] = testDF['RZC_home'] - testDF['RZC_away']
testDF['BRY_diff'] = testDF['BRY_home'] - testDF['BRY_away']
testDF['BPY_diff'] = testDF['BPY_home'] - testDF['BPY_away']
testDF['SRP_diff'] = testDF['SRP_home'] - testDF['SRP_away']
testDF['S1RP_diff'] = testDF['S1RP_home'] - testDF['S1RP_away']
testDF['S2RP_diff'] = testDF['S2RP_home'] - testDF['S2RP_away']
testDF['S3RP_diff'] = testDF['S3RP_home'] - testDF['S3RP_away']
testDF['SPP_diff'] = testDF['SPP_home'] - testDF['SPP_away']
testDF['S1PP_diff'] = testDF['S1PP_home'] - testDF['S1PP_away']
testDF['S2PP_diff'] = testDF['S2PP_home'] - testDF['S2PP_away']
testDF['S3PP_diff'] = testDF['S3PP_home'] - testDF['S3PP_away']
testDF['LEA_diff'] = testDF['LEA_home'] - testDF['LEA_away']
testDF['LEY_diff'] = testDF['LEY_home'] - testDF['LEY_away']
testDF['LTA_diff'] = testDF['LTA_home'] - testDF['LTA_away']
testDF['LTY_diff'] = testDF['LTY_home'] - testDF['LTY_away']
testDF['LGA_diff'] = testDF['LGA_home'] - testDF['LGA_away']
testDF['LGY_diff'] = testDF['LGY_home'] - testDF['LGY_away']
testDF['MDA_diff'] = testDF['MDA_home'] - testDF['MDA_away']
testDF['MDY_diff'] = testDF['MDY_home'] - testDF['MDY_away']
testDF['RGA_diff'] = testDF['RGA_home'] - testDF['RGA_away']
testDF['RGY_diff'] = testDF['RGY_home'] - testDF['RGY_away']
testDF['RTA_diff'] = testDF['RTA_home'] - testDF['RTA_away']
testDF['RTY_diff'] = testDF['RTY_home'] - testDF['RTY_away']
testDF['REA_diff'] = testDF['REA_home'] - testDF['REA_away']
testDF['REY_diff'] = testDF['REY_home'] - testDF['REY_away']
testDF['R1A_diff'] = testDF['R1A_home'] - testDF['R1A_away']
testDF['R1Y_diff'] = testDF['R1Y_home'] - testDF['R1Y_away']
testDF['R2A_diff'] = testDF['R2A_home'] - testDF['R2A_away']
testDF['R2Y_diff'] = testDF['R2Y_home'] - testDF['R2Y_away']
testDF['R3A_diff'] = testDF['R3A_home'] - testDF['R3A_away']
testDF['R3Y_diff'] = testDF['R3Y_home'] - testDF['R3Y_away']
testDF['QBA_diff'] = testDF['QBA_home'] - testDF['QBA_away']
testDF['QBY_diff'] = testDF['QBY_home'] - testDF['QBY_away']
testDF['SLA_diff'] = testDF['SLA_home'] - testDF['SLA_away']
testDF['SLY_diff'] = testDF['SLY_home'] - testDF['SLY_away']
testDF['SMA_diff'] = testDF['SMA_home'] - testDF['SMA_away']
testDF['SMY_diff'] = testDF['SMY_home'] - testDF['SMY_away']
testDF['SRA_diff'] = testDF['SRA_home'] - testDF['SRA_away']
testDF['SRY_diff'] = testDF['SRY_home'] - testDF['SRY_away']
testDF['DLA_diff'] = testDF['DLA_home'] - testDF['DLA_away']
testDF['DLY_diff'] = testDF['DLY_home'] - testDF['DLY_away']
testDF['DMA_diff'] = testDF['DMA_home'] - testDF['DMA_away']
testDF['DMY_diff'] = testDF['DMY_home'] - testDF['DMY_away']
testDF['DRA_diff'] = testDF['DRA_home'] - testDF['DRA_away']
testDF['DRY_diff'] = testDF['DRY_home'] - testDF['DRY_away']
testDF['WR1A_diff'] = testDF['WR1A_home'] - testDF['WR1A_away']
testDF['WR1Y_diff'] = testDF['WR1Y_home'] - testDF['WR1Y_away']
testDF['WR3A_diff'] = testDF['WR3A_home'] - testDF['WR3A_away']
testDF['WR3Y_diff'] = testDF['WR3Y_home'] - testDF['WR3Y_away']
testDF['TEA_diff'] = testDF['TEA_home'] - testDF['TEA_away']
testDF['TEY_diff'] = testDF['TEY_home'] - testDF['TEY_away']
testDF['RBA_diff'] = testDF['RBA_home'] - testDF['RBA_away']
testDF['RBY_diff'] = testDF['RBY_home'] - testDF['RBY_away']
testDF['SGA_diff'] = testDF['SGA_home'] - testDF['SGA_away']
testDF['SGY_diff'] = testDF['SGY_home'] - testDF['SGY_away']
testDF['P1A_diff'] = testDF['P1A_home'] - testDF['P1A_away']
testDF['P1Y_diff'] = testDF['P1Y_home'] - testDF['P1Y_away']
testDF['P2A_diff'] = testDF['P2A_home'] - testDF['P2A_away']
testDF['P2Y_diff'] = testDF['P2Y_home'] - testDF['P2Y_away']
testDF['P3A_diff'] = testDF['P3A_home'] - testDF['P3A_away']
testDF['P3Y_diff'] = testDF['P3Y_home'] - testDF['P3Y_away']
testDF['SPC_diff'] = testDF['SPC_home'] - testDF['SPC_away']
testDF['MPC_diff'] = testDF['MPC_home'] - testDF['MPC_away']
testDF['LPC_diff'] = testDF['LPC_home'] - testDF['LPC_away']
testDF['Q1RA_diff'] = testDF['Q1RA_home'] - testDF['Q1RA_away']
testDF['Q1RY_diff'] = testDF['Q1RY_home'] - testDF['Q1RY_away']
testDF['Q1PA_diff'] = testDF['Q1PA_home'] - testDF['Q1PA_away']
testDF['Q1PY_diff'] = testDF['Q1PY_home'] - testDF['Q1PY_away']
testDF['LCRA_diff'] = testDF['LCRA_home'] - testDF['LCRA_away']
testDF['LCRY_diff'] = testDF['LCRY_home'] - testDF['LCRY_away']
testDF['LCPA_diff'] = testDF['LCPA_home'] - testDF['LCPA_away']
testDF['LCPY_diff'] = testDF['LCPY_home'] - testDF['LCPY_away']
testDF['RZRA_diff'] = testDF['RZRA_home'] - testDF['RZRA_away']
testDF['RZRY_diff'] = testDF['RZRY_home'] - testDF['RZRY_away']
testDF['RZPA_diff'] = testDF['RZPA_home'] - testDF['RZPA_away']
testDF['RZPY_diff'] = testDF['RZPY_home'] - testDF['RZPY_away']
testDF['SKY_diff'] = testDF['SKY_home'] - testDF['SKY_away']
testDF['LBS_diff'] = testDF['LBS_home'] - testDF['LBS_away']
testDF['DBS_diff'] = testDF['DBS_home'] - testDF['DBS_away']
testDF['SFPY_diff'] = testDF['SFPY_home'] - testDF['SFPY_away']
testDF['DRV_diff'] = testDF['DRV_home'] - testDF['DRV_away']
testDF['NPY_diff'] = testDF['NPY_home'] - testDF['NPY_away']
testDF['TB_diff'] = testDF['TB_home'] - testDF['TB_away']
testDF['I20_diff'] = testDF['I20_home'] - testDF['I20_away']
testDF['RTD_diff'] = testDF['RTD_home'] - testDF['RTD_away']
testDF['LNR_diff'] = testDF['LNR_home'] - testDF['LNR_away']
testDF['LNP_diff'] = testDF['LNP_home'] - testDF['LNP_away']
testDF['LBR_diff'] = testDF['LBR_home'] - testDF['LBR_away']
testDF['LBP_diff'] = testDF['LBP_home'] - testDF['LBP_away']
testDF['DBR_diff'] = testDF['DBR_home'] - testDF['DBR_away']
testDF['DBP_diff'] = testDF['DBP_home'] - testDF['DBP_away']
testDF['NHA_diff'] = testDF['NHA_home'] - testDF['NHA_away']
testDF['S3A_diff'] = testDF['S3A_home'] - testDF['S3A_away']
testDF['S3C_diff'] = testDF['S3C_home'] - testDF['S3C_away']
testDF['L3A_diff'] = testDF['L3A_home'] - testDF['L3A_away']
testDF['L3C_diff'] = testDF['L3C_home'] - testDF['L3C_away']
testDF['STF_diff'] = testDF['STF_home'] - testDF['STF_away']
testDF['DP_diff'] = testDF['DP_home'] - testDF['DP_away']
testDF['FSP_diff'] = testDF['FSP_home'] - testDF['FSP_away']
testDF['OHP_diff'] = testDF['OHP_home'] - testDF['OHP_away']
testDF['PBEP_diff'] = testDF['PBEP_home'] - testDF['PBEP_away']
testDF['DLP_diff'] = testDF['DLP_home'] - testDF['DLP_away']
testDF['DSP_diff'] = testDF['DSP_home'] - testDF['DSP_away']
testDF['DMP_diff'] = testDF['DMP_home'] - testDF['DMP_away']
testDF['PFN_diff'] = testDF['PFN_home'] - testDF['PFN_away']

# %%
cols = ['game_id','year','week','day','away_team','home_team','stadium','temperature','humidity','wind_speed','wind_direction','conditions','surface','over_or_under','visitor_point_spread','away_score','home_score','winner','score_diff','1QP_diff','2QP_diff','3QP_diff','4QP_diff','RFD_diff','PFD_diff','IFD_diff','RY_diff','RA_diff','PY_diff','PA_diff','PC_diff','SK_diff','INT_diff','FUM_diff','PU_diff','GPY_diff','PR_diff','PRY_diff','KR_diff','KRY_diff','IR_diff','IRY_diff','PEN_diff','TOP_diff','TD_diff','TDR_diff','TDP_diff','TDT_diff','FGM_diff','FGAT_diff','FGY_diff','RZA_diff','RZC_diff','BRY_diff','BPY_diff','SRP_diff','S1RP_diff','S2RP_diff','S3RP_diff','SPP_diff','S1PP_diff','S2PP_diff','S3PP_diff','LEA_diff','LEY_diff','LTA_diff','LTY_diff','LGA_diff','LGY_diff','MDA_diff','MDY_diff','RGA_diff','RGY_diff','RTA_diff','RTY_diff','REA_diff','REY_diff','R1A_diff','R1Y_diff','R2A_diff','R2Y_diff','R3A_diff','R3Y_diff','QBA_diff','QBY_diff','SLA_diff','SLY_diff','SMA_diff','SMY_diff','SRA_diff','SRY_diff','DLA_diff','DLY_diff','DMA_diff','DMY_diff','DRA_diff','DRY_diff','WR1A_diff','WR1Y_diff','WR3A_diff','WR3Y_diff','TEA_diff','TEY_diff','RBA_diff','RBY_diff','SGA_diff','SGY_diff','P1A_diff','P1Y_diff','P2A_diff','P2Y_diff','P3A_diff','P3Y_diff','SPC_diff','MPC_diff','LPC_diff','Q1RA_diff','Q1RY_diff','Q1PA_diff','Q1PY_diff','LCRA_diff','LCRY_diff','LCPA_diff','LCPY_diff','RZRA_diff','RZRY_diff','RZPA_diff','RZPY_diff','SKY_diff','LBS_diff','DBS_diff','SFPY_diff','DRV_diff','NPY_diff','TB_diff','I20_diff','RTD_diff','LNR_diff','LNP_diff','LBR_diff','LBP_diff','DBR_diff','DBP_diff','NHA_diff','S3A_diff','S3C_diff','L3A_diff','L3C_diff','STF_diff','DP_diff','FSP_diff','OHP_diff','PBEP_diff','DLP_diff','DSP_diff','DMP_diff','PFN_diff']

# %%
trainDF = trainDF[cols]
testDF = testDF[cols]

# %%
trainDF.to_csv('trainNFL_diff.csv')
testDF.to_csv('testNFL_diff.csv')
